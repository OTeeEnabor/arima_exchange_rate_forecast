# %% [markdown]
# # Import modules

# %%
from google.colab import auth
import gspread
from google.auth import default

import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objs as go

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from matplotlib import pyplot as plt
from matplotlib import pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.26.15)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (63.4.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pmdarima) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3

# %%
from pmdarima.arima import auto_arima, ADFTest

# %% [markdown]
# Connect Google Sheets

# %%
# authenticating to Google
auth.authenticate_user()
creds,_ = default()
gc =  gspread.authorize(creds)

# %%
 exchange_sheet = gc.open('Exchange Rate').sheet1
# get all values
rows = exchange_sheet.get_all_values()
# convert to df
exchange_df = pd.DataFrame(rows)
# show the head of data frame
exchange_df.head()
# Out:
#             0                     1                2                3  \
# 0    Date/USD                   WVT              ITL              ITK
# 1        Date  South African (Rand)  Mauritian Rupee  Kenyan Shilling
# 2  2022-03-12                 15.03            44.48           114.16
# 3  2022-03-13                 15.03            44.50           114.19
# 4  2022-03-14                 15.02            44.46           114.01
#
#                 4                   5              6
# 0             ITN                 ITM            ITB
# 1  Nigerian Naira  Mozambique Metical  Botswana Pula
# 2          415.69               63.83          11.56
# 3          415.80               63.84          11.56
# 4          415.22               63.80          11.55

# %%
exchange_df = exchange_df.iloc[1:]
exchange_df.head()
# Out:
#             0                     1                2                3  \
# 1        Date  South African (Rand)  Mauritian Rupee  Kenyan Shilling
# 2  2022-03-12                 15.03            44.48           114.16
# 3  2022-03-13                 15.03            44.50           114.19
# 4  2022-03-14                 15.02            44.46           114.01
# 5  2022-03-15                 15.12            44.40           114.25
#
#                 4                   5              6
# 1  Nigerian Naira  Mozambique Metical  Botswana Pula
# 2          415.69               63.83          11.56
# 3          415.80               63.84          11.56
# 4          415.22               63.80          11.55
# 5          415.79               63.84          11.62

# %%
# check datatypes of each variable in the dataset
exchange_df.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# dtype: object

# %%
exchange_df.columns= exchange_df.iloc[0]

# %%
exchange_df.columns
# Out:
# Index(['Date', 'South African (Rand)', 'Mauritian Rupee', 'Kenyan Shilling',
#        'Nigerian Naira', 'Mozambique Metical', 'Botswana Pula'],
#       dtype='object', name=1)

# %%
exchange_df = exchange_df.iloc[1:]
exchange_df.head()
# Out:
# 1        Date South African (Rand) Mauritian Rupee Kenyan Shilling  \
# 2  2022-03-12                15.03           44.48          114.16
# 3  2022-03-13                15.03           44.50          114.19
# 4  2022-03-14                15.02           44.46          114.01
# 5  2022-03-15                15.12           44.40          114.25
# 6  2022-03-16                15.08           44.33          114.24
#
# 1 Nigerian Naira Mozambique Metical Botswana Pula
# 2         415.69              63.83         11.56
# 3         415.80              63.84         11.56
# 4         415.22              63.80         11.55
# 5         415.79              63.84         11.62
# 6         415.74              63.81         11.63

# %%
exchange_df[['South African (Rand)', 'Mauritian Rupee', 'Kenyan Shilling','Nigerian Naira', 'Mozambique Metical', 'Botswana Pula']] = exchange_df[['South African (Rand)', 'Mauritian Rupee', 'Kenyan Shilling','Nigerian Naira', 'Mozambique Metical', 'Botswana Pula']].apply(pd.to_numeric)

# %%
exchange_df.dtypes
# Out:
# 1
# Date                     object
# South African (Rand)    float64
# Mauritian Rupee         float64
# Kenyan Shilling         float64
# Nigerian Naira          float64
# Mozambique Metical      float64
# Botswana Pula           float64
# dtype: object

# %%
exchange_df = exchange_df.reset_index(drop=True)

# %%
exchange_df.head()
# Out:
# 1        Date  South African (Rand)  Mauritian Rupee  Kenyan Shilling  \
# 0  2022-03-12                 15.03            44.48           114.16
# 1  2022-03-13                 15.03            44.50           114.19
# 2  2022-03-14                 15.02            44.46           114.01
# 3  2022-03-15                 15.12            44.40           114.25
# 4  2022-03-16                 15.08            44.33           114.24
#
# 1  Nigerian Naira  Mozambique Metical  Botswana Pula
# 0          415.69               63.83          11.56
# 1          415.80               63.84          11.56
# 2          415.22               63.80          11.55
# 3          415.79               63.84          11.62
# 4          415.74               63.81          11.63

# %%
exchange_df['Date'] = pd.to_datetime(exchange_df['Date'])

# %%
exchange_df.rename(columns =
                   {"South African (Rand)": "ZAR",
                    "Mauritian Rupee": "MUR",
                    "Kenyan Shilling": "KSH",
                    "Nigerian Naira": "NRA",
                    "Mozambique Metical":"MZM",
                    "Botswana Pula": "BPU"}, inplace=True)

# %%
exchange_df.head()
# Out:
# 1       Date    ZAR    MUR     KSH     NRA    MZM    BPU
# 0 2022-03-12  15.03  44.48  114.16  415.69  63.83  11.56
# 1 2022-03-13  15.03  44.50  114.19  415.80  63.84  11.56
# 2 2022-03-14  15.02  44.46  114.01  415.22  63.80  11.55
# 3 2022-03-15  15.12  44.40  114.25  415.79  63.84  11.62
# 4 2022-03-16  15.08  44.33  114.24  415.74  63.81  11.63

# %% [markdown]
# # Distribution Plots

# %%
currency_list = ['ZAR', 'MUR', 'KSH', 'NRA','MZM','BPU']

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace=0.5)
plt.suptitle('Currency Exchange Rate to USD', fontsize=18,y=1)

# loop through the length of currencies and keep track of index
for n, currency in enumerate(currency_list):
  # add new subplot iteratively
  ax = plt.subplot(3,2,n+1)
  exchange_df.plot(x='Date',y=currency,ax=ax, legend=None)
  # chart formating
  ax.set_title(currency.upper())
  # ax.get_legend().remove()
  ax.set_xlabel("")
  # chart formating
  ax.set_title(currency.upper())
  # ax.get_legend().remove()
  ax.set_xlabel("")

# %% [markdown]
# ## Determine Stationarity
# Is it a stationary series?
# 1. The mean of the time series should not be a finction of time. It should be constant.
# 2. The variance of the time series should not be a function of time.
# 3. The covariance of the ith term and the (i+m)th term should not be a function of time.
#
# The statistical properties over time frame have to be constant and autocovariance must not fluctuate with time.
#
#  ## Resample the data
# Daily data for time series usually contains too much variation. Therefore, each series will be resampled by week. This resampled time series will be used to predict the exchange rate against the USD.

# %%
# to resample the index of exchange df must be in date time
exchange_df.set_index('Date', inplace=True)

# %%
# initialize an empty dataframe for the weekly sample
week_exchange_df = pd.DataFrame()

# %%
for i in range(len(currency_list)):
  week_series = exchange_df[currency_list[i]].resample('W').mean()
  week_exchange_df[currency_list[i]] = week_series.values
  if i == len(currency_list) - 1:
    week_exchange_df['Date'] = week_series.index
    week_exchange_df.set_index('Date', inplace=True)

# %%
week_exchange_df.head()
# Out:
#                   ZAR        MUR         KSH         NRA        MZM        BPU
# Date
# 2022-03-13  15.030000  44.490000  114.175000  415.745000  63.835000  11.560000
# 2022-03-20  14.975714  44.337143  114.257143  415.692857  63.815714  11.584286
# 2022-03-27  14.741429  44.360000  114.467143  415.705714  63.814286  11.528571
# 2022-04-03  14.584286  44.707143  114.958571  415.841429  63.811429  11.458571
# 2022-04-10  14.661429  44.918571  115.160000  415.467143  63.821429  11.521429

# %%
week_exchange_df['ZAR'].name
# Out:
# 'ZAR'

# %% [markdown]
# ### Perform Dickey Fuller test
#
# #### Stationarity Check
#
# The Dickey Fuller test is used to check the stationarity of the series. The test determines how stringly a time series is defined by a trend. The null hypothesis of the test is that time series is not stationary( has some time-dependent structure).
#
# The test result is made up of a Test Statistic and some Critical Values for different confidence levels. If **P-VALUE** is less than the **significance level** , the null hypothesis is rejected and the series is stationary.

# %%
def stationarity_check(date,timeseries):
  # determine the rolling statistics
  rolling_mean = timeseries.rolling(window=10, center=False).mean()
  rolling_std = timeseries.rolling(window=10, center=False).std()
  # plot rolling statistics
  standard = plt.plot(date, timeseries, color='blue', label='original' )
  mean = plt.plot(date, rolling_mean, color='red', label='mean-mean' )
  std = plt.plot(date, rolling_std, color='black', label='std-rolling')
  plt.legend(loc='best')
  plt.title(f'Rolling Mean & standard deviation for {timeseries.name}/USD ')
  plt.show(block=False)
  #Perform Dickey-Fuller test:
  print ('Results of Dickey-Fuller Test:')
  dickey_fuller_test = adfuller(timeseries, autolag='AIC')
  dfresults = pd.Series(dickey_fuller_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
  for key,value in dickey_fuller_test[4].items():
    dfresults['Critical Value (%s)'%key] = value
  print (dfresults)

# %%
for currency in currency_list:
  stationarity_check(week_exchange_df.index, week_exchange_df[currency])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.554127
# p-value                         0.506586
# #Lags Used                      1.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.221624
# p-value                         0.664225
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  0.603552
# p-value                         0.987703
# #Lags Used                      6.000000
# Number of Observations Used    48.000000
# Critical Value (1%)            -3.574589
# Critical Value (5%)            -2.923954
# Critical Value (10%)           -2.600039
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.760144
# p-value                         0.830550
# #Lags Used                      1.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.017374
# p-value                         0.001322
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.916565
# p-value                         0.324309
# #Lags Used                      1.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64

# %% [markdown]
# Based on the results of the stationarity task, **ZAR, MUR, KSH, NRA, and BPU** time series are not stationary due to the p-value being **greater than 5%**. ACF plots were created for each time series to further verify the non-stationarity.
#
# The ACF plots show us that the majority of these time series data is not stationary. For a stationary time series, the ACF plot will drop to zero relatively quickly, while ACF for non-stationary series descreases slowly.

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace=0.5)
plt.suptitle('ACF plots', fontsize=18,y=1)

# loop through the length of currencies and keep track of index
for n, currency in enumerate(currency_list):
  # add new subplot iteratively
  ax = plt.subplot(3,2,n+1)
  plot_acf(x=week_exchange_df[currency],ax=ax)
  # chart formating
  ax.set_title(currency.upper())
  # ax.get_legend().remove()
  ax.set_xlabel("")

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace=0.5)
plt.suptitle('PACF plots', fontsize=18,y=1)

# loop through the length of currencies and keep track of index
for n, currency in enumerate(currency_list):
  # add new subplot iteratively
  ax = plt.subplot(3,2,n+1)
  plot_pacf(x=week_exchange_df[currency],ax=ax)
  # chart formating
  ax.set_title(currency.upper())
  # ax.get_legend().remove()
  ax.set_xlabel("")

# %% [markdown]
# Lets see the seasonal and trend components of each time series.

# %%
non_stationary_currency_list = ['ZAR', 'MUR', 'KSH','NRA', 'BPU']

# %%
for n, currency in enumerate(currency_list):
  result = seasonal_decompose(week_exchange_df[currency].tolist(), model='additive', period=1)
  print(currency)
  result.plot()
# Out:
# ZAR
# MUR
# KSH
# NRA
# MZM
# BPU

# %% [markdown]
# Lets apply log transformation to each time series to remove the trend component.

# %%
for n, currency in enumerate(currency_list):
  week_exchange_df[f'{currency}_log'] = np.log(week_exchange_df[currency])

# %%
for currency in currency_list:
  stationarity_check(week_exchange_df.index, week_exchange_df[f'{currency}_log'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.617895
# p-value                         0.473833
# #Lags Used                      1.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.233135
# p-value                         0.659182
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  0.318169
# p-value                         0.978163
# #Lags Used                      6.000000
# Number of Observations Used    48.000000
# Critical Value (1%)            -3.574589
# Critical Value (5%)            -2.923954
# Critical Value (10%)           -2.600039
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.739844
# p-value                         0.836158
# #Lags Used                      1.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.016673
# p-value                         0.001326
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.941453
# p-value                         0.312819
# #Lags Used                      1.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64

# %%
for n,currency in enumerate(currency_list):
  week_exchange_df[f'{currency}_log_dif'] = week_exchange_df[f'{currency}_log'] - week_exchange_df[f'{currency}_log'].shift()

# %%
week_exchange_df.columns
# Out:
# Index(['ZAR', 'MUR', 'KSH', 'NRA', 'MZM', 'BPU', 'ZAR_log', 'MUR_log',
#        'KSH_log', 'NRA_log', 'MZM_log', 'BPU_log', 'ZAR_log_dif',
#        'MUR_log_dif', 'KSH_log_dif', 'NRA_log_dif', 'MZM_log_dif',
#        'BPU_log_dif'],
#       dtype='object')

# %%
week_exchange_df= week_exchange_df.fillna(0)

# %%
for currency in currency_list:
  stationarity_check(week_exchange_df.index, week_exchange_df[f'{currency}_log_dif'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.857774
# p-value                         0.000042
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -6.963640e+00
# p-value                        9.030690e-10
# #Lags Used                     0.000000e+00
# Number of Observations Used    5.400000e+01
# Critical Value (1%)           -3.557709e+00
# Critical Value (5%)           -2.916770e+00
# Critical Value (10%)          -2.596222e+00
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.520980
# p-value                         0.000180
# #Lags Used                      5.000000
# Number of Observations Used    49.000000
# Critical Value (1%)            -3.571472
# Critical Value (5%)            -2.922629
# Critical Value (10%)           -2.599336
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.759491
# p-value                         0.064297
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -6.177486e+00
# p-value                        6.576664e-08
# #Lags Used                     3.000000e+00
# Number of Observations Used    5.100000e+01
# Critical Value (1%)           -3.565624e+00
# Critical Value (5%)           -2.920142e+00
# Critical Value (10%)          -2.598015e+00
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.775688
# p-value                         0.000061
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64

# %% [markdown]
# ### Plot ACF and PACF Plots
#
# Now that each time series has been stationarized, time to use the PACF and ACF plots to determine the PDQ terms for the ARIMA model.

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace=0.5)
plt.suptitle('ACF plots', fontsize=18,y=1)

# loop through the length of currencies and keep track of index
for n, currency in enumerate(currency_list):
  # add new subplot iteratively
  ax = plt.subplot(3,2,n+1)
  plot_acf(x=week_exchange_df[f'{currency}_log_dif'],ax=ax)
  # chart formating
  ax.set_title(currency.upper())
  # ax.get_legend().remove()
  ax.set_xlabel("")

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace=0.5)
plt.suptitle('PACF plots', fontsize=18,y=1)

# loop through the length of currencies and keep track of index
for n, currency in enumerate(currency_list):
  # add new subplot iteratively
  ax = plt.subplot(3,2,n+1)
  plot_pacf(x=week_exchange_df[f'{currency}_log_dif'],ax=ax)
  # chart formating
  ax.set_title(currency.upper())
  # ax.get_legend().remove()
  ax.set_xlabel("")

# %% [markdown]
# ### Determine MZM ACF and PACF
#
# The daily timeseries of the Mozambican Meticals is stationary.

# %%
week_exchange_df['MZM']
# Out:
# Date
# 2022-03-13    63.835000
# 2022-03-20    63.815714
# 2022-03-27    63.814286
# 2022-04-03    63.811429
# 2022-04-10    63.821429
# 2022-04-17    63.830000
# 2022-04-24    63.808571
# 2022-05-01    63.824286
# 2022-05-08    63.824286
# 2022-05-15    63.805714
# 2022-05-22    63.807143
# 2022-05-29    63.817143
# 2022-06-05    63.837143
# 2022-06-12    63.844286
# 2022-06-19    63.852857
# 2022-06-26    63.851910
# 2022-07-03    63.827841
# 2022-07-10    63.824401
# 2022-07-17    63.817090
# 2022-07-24    63.805034
# 2022-07-31    63.819704
# 2022-08-07    63.839394
# 2022-08-14    63.850551
# 2022-08-21    63.833627
# 2022-08-28    63.848107
# 2022-09-04    63.839842
# 2022-09-11    63.855097
# 2022-09-18    63.829409
# 2022-09-25    63.846288
# 2022-10-02    63.901190
# 2022-10-09    63.868671
# 2022-10-16    63.849658
# 2022-10-23    63.844494
# 2022-10-30    63.813197
# 2022-11-06    63.832218
# 2022-11-13    63.849788
# 2022-11-20    63.824747
# 2022-11-27    63.843008
# 2022-12-04    63.840511
# 2022-12-11    63.853385
# 2022-12-18    63.858766
# 2022-12-25    63.849693
# 2023-01-01    63.837029
# 2023-01-08    63.860045
# 2023-01-15    63.853908
# 2023-01-22    63.872997
# 2023-01-29    63.863611
# 2023-02-05    63.851437
# 2023-02-12    63.853183
# 2023-02-19    63.826505
# 2023-02-26    63.922481
# 2023-03-05    63.886152
# 2023-03-12    63.844620
# 2023-03-19    63.846653
# 2023-03-26    63.853370
# Name: MZM, dtype: float64

# %%
stationarity_check(week_exchange_df['MZM'].index, week_exchange_df['MZM'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.017374
# p-value                         0.001322
# #Lags Used                      0.000000
# Number of Observations Used    54.000000
# Critical Value (1%)            -3.557709
# Critical Value (5%)            -2.916770
# Critical Value (10%)           -2.596222
# dtype: float64

# %%
plot_acf(x=week_exchange_df['MZM'])

# %%
plot_pacf(x=week_exchange_df['MZM'])

# %% [markdown]
# P=1,Q=1,d=1

# %% [markdown]
# # Predict with Arima

# %%
# ZAR
model_zar = ARIMA(week_exchange_df['ZAR_log_dif'], order=(2,2,1))
zar_results = model_zar.fit()
plt.plot(week_exchange_df.index, week_exchange_df['ZAR_log_dif'])
plt.plot(week_exchange_df.index, zar_results.fittedvalues, color='red')

# %%
currency_dif_list = ['ZAR_log_dif','MUR_log_dif', 'KSH_log_dif', 'NRA_log_dif', 'MZM_log_dif', 'BPU_log_dif']
currency_orders_list = [(2,2,1),(2,1,1),(2,3,1),(2,3,1),(18,3,1),(3,2,1)]

for i in range(len(currency_list)):
  model = ARIMA(week_exchange_df[currency_dif_list[i]], order=currency_orders_list[i])
  model_results = model.fit()

  week_exchange_df[f'{currency_dif_list[i]}_pred'] = np.array(model_results.fittedvalues)

# %%
week_exchange_df.head()
# Out:
#                   ZAR        MUR         KSH         NRA        MZM  \
# Date
# 2022-03-13  15.030000  44.490000  114.175000  415.745000  63.835000
# 2022-03-20  14.975714  44.337143  114.257143  415.692857  63.815714
# 2022-03-27  14.741429  44.360000  114.467143  415.705714  63.814286
# 2022-04-03  14.584286  44.707143  114.958571  415.841429  63.811429
# 2022-04-10  14.661429  44.918571  115.160000  415.467143  63.821429
#
#                   BPU   ZAR_log   MUR_log   KSH_log   NRA_log  ...  \
# Date                                                           ...
# 2022-03-13  11.560000  2.710048  3.795264  4.737732  6.030072  ...
# 2022-03-20  11.584286  2.706430  3.791823  4.738452  6.029947  ...
# 2022-03-27  11.528571  2.690662  3.792338  4.740288  6.029978  ...
# 2022-04-03  11.458571  2.679945  3.800133  4.744572  6.030304  ...
# 2022-04-10  11.521429  2.685220  3.804851  4.746322  6.029404  ...
#
#             KSH_log_dif  NRA_log_dif  MZM_log_dif  BPU_log_dif  \
# Date
# 2022-03-13     0.000000     0.000000     0.000000     0.000000
# 2022-03-20     0.000719    -0.000125    -0.000302     0.002099
# 2022-03-27     0.001836     0.000031    -0.000022    -0.004821
# 2022-04-03     0.004284     0.000326    -0.000045    -0.006090
# 2022-04-10     0.001751    -0.000900     0.000157     0.005471
#
#             ZAR_log_dif_pred  MUR_log_dif_pred  KSH_log_dif_pred  \
# Date
# 2022-03-13          0.000000          0.000000          0.000000
# 2022-03-20          0.000000          0.000000          0.000000
# 2022-03-27         -0.007237         -0.001663          0.001798
# 2022-04-03         -0.022585         -0.001076          0.003351
# 2022-04-10         -0.017404          0.001141          0.007414
#
#             NRA_log_dif_pred  MZM_log_dif_pred  BPU_log_dif_pred
# Date
# 2022-03-13          0.000000          0.000000          0.000000
# 2022-03-20          0.000000          0.000000          0.000000
# 2022-03-27         -0.000314         -0.000755          0.004197
# 2022-04-03          0.000469          0.000839         -0.006793
# 2022-04-10          0.000858         -0.000369         -0.007340
#
# [5 rows x 24 columns]

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace=0.5)
plt.suptitle('ARIMA plots', fontsize=18,y=1)
# loop through the length of currencies and keep track of index
for  i in range(len(currency_dif_list)):
  # add new subplot iteratively
  ax = plt.subplot(3,2,i+1)
  print(currency_dif_list[i])
  week_exchange_df.plot(y = f'{currency_dif_list[i]}', ax=ax, use_index=True, legend=None)
  week_exchange_df.plot(y=f'{currency_dif_list[i]}_pred',ax=ax, use_index=True,legend=None)
  # chart formating
  ax.set_title(currency_list[i].upper())
  # ax.get_legend().remove()
  ax.set_xlabel("")
# Out:
# ZAR_log_dif
# MUR_log_dif
# KSH_log_dif
# NRA_log_dif
# MZM_log_dif
# BPU_log_dif

# %% [markdown]
# Plot the residuals

# %%
for i in range(len(currency_list)):
  model = ARIMA(week_exchange_df[currency_dif_list[i]], order=currency_orders_list[i])
  model_results = model.fit()
  print(model_results.summary())
  residuals = pd.DataFrame(model_results.resid)
  residuals.plot(kind='kde')
  print(residuals.describe())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            ZAR_log_dif   No. Observations:                   54
# Model:                 ARIMA(2, 2, 1)   Log Likelihood                 140.355
# Date:                Tue, 14 Mar 2023   AIC                           -272.711
# Time:                        12:09:35   BIC                           -264.906
# Sample:                    03-13-2022   HQIC                          -269.718
#                          - 03-19-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3469      0.165     -2.103      0.035      -0.670      -0.024
# ar.L2         -0.0968      0.119     -0.815      0.415      -0.329       0.136
# ma.L1         -0.9928      1.059     -0.937      0.349      -3.068       1.083
# sigma2         0.0002      0.000      0.984      0.325      -0.000       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.30
# Prob(Q):                              0.94   Prob(JB):                         0.86
# Heteroskedasticity (H):               0.32   Skew:                            -0.18
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                0
# count  54.000000
# mean   -0.000354
# std     0.016173
# min    -0.040705
# 25%    -0.007089
# 50%    -0.000972
# 75%     0.010464
# max     0.037718
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            MUR_log_dif   No. Observations:                   54
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                 169.041
# Date:                Tue, 14 Mar 2023   AIC                           -330.081
# Time:                        12:09:35   BIC                           -322.200
# Sample:                    03-13-2022   HQIC                          -327.051
#                          - 03-19-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0217      0.304     -0.071      0.943      -0.617       0.573
# ar.L2          0.0181      0.187      0.097      0.923      -0.349       0.385
# ma.L1         -0.8912      0.166     -5.376      0.000      -1.216      -0.566
# sigma2      9.618e-05   1.42e-05      6.751      0.000    6.83e-05       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):               108.65
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.24   Skew:                            -2.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                0
# count  54.000000
# mean    0.001037
# std     0.009949
# min    -0.043369
# 25%    -0.000183
# 50%     0.002977
# 75%     0.005514
# max     0.015114
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            KSH_log_dif   No. Observations:                   54
# Model:                 ARIMA(2, 3, 1)   Log Likelihood                 248.126
# Date:                Tue, 14 Mar 2023   AIC                           -488.253
# Time:                        12:09:36   BIC                           -480.525
# Sample:                    03-13-2022   HQIC                          -485.300
#                          - 03-19-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5700      0.147     -3.885      0.000      -0.858      -0.282
# ar.L2         -0.1780      0.180     -0.992      0.321      -0.530       0.174
# ma.L1         -0.9249      0.210     -4.394      0.000      -1.337      -0.512
# sigma2      3.246e-06   8.46e-07      3.838      0.000    1.59e-06     4.9e-06
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.13   Jarque-Bera (JB):                 2.11
# Prob(Q):                              0.02   Prob(JB):                         0.35
# Heteroskedasticity (H):               2.68   Skew:                            -0.41
# Prob(H) (two-sided):                  0.05   Kurtosis:                         3.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                0
# count  54.000000
# mean   -0.000011
# std     0.001867
# min    -0.005663
# 25%    -0.001005
# 50%     0.000227
# 75%     0.001262
# max     0.004455
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            NRA_log_dif   No. Observations:                   54
# Model:                 ARIMA(2, 3, 1)   Log Likelihood                 216.835
# Date:                Tue, 14 Mar 2023   AIC                           -425.670
# Time:                        12:09:37   BIC                           -417.943
# Sample:                    03-13-2022   HQIC                          -422.718
#                          - 03-19-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6184      0.174     -3.561      0.000      -0.959      -0.278
# ar.L2         -0.2400      0.170     -1.415      0.157      -0.572       0.092
# ma.L1         -0.6337      0.266     -2.383      0.017      -1.155      -0.113
# sigma2      1.145e-05   3.24e-06      3.539      0.000    5.11e-06    1.78e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.99   Jarque-Bera (JB):                 4.01
# Prob(Q):                              0.05   Prob(JB):                         0.13
# Heteroskedasticity (H):               6.48   Skew:                            -0.06
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                   0
# count  5.400000e+01
# mean   2.702506e-05
# std    3.329377e-03
# min   -1.059921e-02
# 25%   -1.742596e-03
# 50%   -7.293251e-07
# 75%    2.147567e-03
# max    9.209466e-03
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            MZM_log_dif   No. Observations:                   54
# Model:                ARIMA(18, 3, 1)   Log Likelihood                 249.529
# Date:                Tue, 14 Mar 2023   AIC                           -459.058
# Time:                        12:09:41   BIC                           -420.422
# Sample:                    03-13-2022   HQIC                          -444.294
#                          - 03-19-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       -1.13e-05      0.257   -4.4e-05      1.000      -0.504       0.504
# ar.L2       1.813e-05      1.110   1.63e-05      1.000      -2.175       2.175
# ar.L3       4.771e-06      1.595   2.99e-06      1.000      -3.125       3.125
# ar.L4      -6.175e-06      1.811  -3.41e-06      1.000      -3.549       3.549
# ar.L5       7.444e-06      2.017   3.69e-06      1.000      -3.953       3.953
# ar.L6       -1.86e-06      2.342  -7.94e-07      1.000      -4.591       4.591
# ar.L7       1.046e-06      2.989    3.5e-07      1.000      -5.858       5.858
# ar.L8       2.456e-06      3.694   6.65e-07      1.000      -7.240       7.240
# ar.L9       7.273e-07      4.246   1.71e-07      1.000      -8.323       8.323
# ar.L10     -1.305e-06      4.571  -2.86e-07      1.000      -8.958       8.958
# ar.L11      6.599e-06      4.704    1.4e-06      1.000      -9.219       9.219
# ar.L12     -5.252e-06      4.675  -1.12e-06      1.000      -9.163       9.163
# ar.L13      5.978e-06      4.328   1.38e-06      1.000      -8.483       8.483
# ar.L14     -1.252e-06      3.743  -3.34e-07      1.000      -7.336       7.336
# ar.L15      1.005e-06      3.117   3.23e-07      1.000      -6.109       6.109
# ar.L16      2.697e-06      2.507   1.08e-06      1.000      -4.913       4.913
# ar.L17      3.732e-07      1.706   2.19e-07      1.000      -3.343       3.343
# ar.L18     -1.053e-06      0.923  -1.14e-06      1.000      -1.809       1.809
# ma.L1      -6.328e-06      0.257  -2.46e-05      1.000      -0.504       0.504
# sigma2      3.322e-06   1.23e-06      2.700      0.007    9.11e-07    5.73e-06
# ===================================================================================
# Ljung-Box (L1) (Q):                  29.02   Jarque-Bera (JB):                20.27
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.70   Skew:                             0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.65e+18. Standard errors may be unstable.
#                0
# count  54.000000
# mean    0.000010
# std     0.001784
# min    -0.006357
# 25%    -0.000925
# 50%    -0.000021
# 75%     0.000771
# max     0.005980
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            BPU_log_dif   No. Observations:                   54
# Model:                 ARIMA(3, 2, 1)   Log Likelihood                 163.891
# Date:                Tue, 14 Mar 2023   AIC                           -317.783
# Time:                        12:09:42   BIC                           -308.027
# Sample:                    03-13-2022   HQIC                          -314.043
#                          - 03-19-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3417      0.173     -1.978      0.048      -0.680      -0.003
# ar.L2         -0.2420      0.155     -1.564      0.118      -0.545       0.061
# ar.L3          0.0236      0.189      0.125      0.900      -0.346       0.394
# ma.L1         -0.9707      0.275     -3.530      0.000      -1.510      -0.432
# sigma2      9.922e-05   3.21e-05      3.090      0.002    3.63e-05       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.15
# Prob(Q):                              0.99   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.35   Skew:                             0.11
# Prob(H) (two-sided):                  0.04   Kurtosis:                         2.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                0
# count  54.000000
# mean   -0.000362
# std     0.010206
# min    -0.019483
# 25%    -0.007500
# 50%     0.000723
# 75%     0.003777
# max     0.026900

# %%
# scale predictions back to original
def rescale(unscaled_series, unscaled_series_log):
  # calculate cumulative sum - why?
  unscaled_series_cumsum = unscaled_series.cumsum()
  unscaled_series_log = pd.Series(unscaled_series_log.iloc[0], index = unscaled_series_log.index)
  unscaled_series_log = unscaled_series_log.add(unscaled_series_cumsum,fill_value=0)
  unscaled_series_ = np.exp(unscaled_series_log)
  return unscaled_series_

# %%
week_exchange_df.head()
# Out:
#                   ZAR        MUR         KSH         NRA        MZM  \
# Date
# 2022-03-13  15.030000  44.490000  114.175000  415.745000  63.835000
# 2022-03-20  14.975714  44.337143  114.257143  415.692857  63.815714
# 2022-03-27  14.741429  44.360000  114.467143  415.705714  63.814286
# 2022-04-03  14.584286  44.707143  114.958571  415.841429  63.811429
# 2022-04-10  14.661429  44.918571  115.160000  415.467143  63.821429
#
#                   BPU   ZAR_log   MUR_log   KSH_log   NRA_log  ...  \
# Date                                                           ...
# 2022-03-13  11.560000  2.710048  3.795264  4.737732  6.030072  ...
# 2022-03-20  11.584286  2.706430  3.791823  4.738452  6.029947  ...
# 2022-03-27  11.528571  2.690662  3.792338  4.740288  6.029978  ...
# 2022-04-03  11.458571  2.679945  3.800133  4.744572  6.030304  ...
# 2022-04-10  11.521429  2.685220  3.804851  4.746322  6.029404  ...
#
#             KSH_log_dif  NRA_log_dif  MZM_log_dif  BPU_log_dif  \
# Date
# 2022-03-13     0.000000     0.000000     0.000000     0.000000
# 2022-03-20     0.000719    -0.000125    -0.000302     0.002099
# 2022-03-27     0.001836     0.000031    -0.000022    -0.004821
# 2022-04-03     0.004284     0.000326    -0.000045    -0.006090
# 2022-04-10     0.001751    -0.000900     0.000157     0.005471
#
#             ZAR_log_dif_pred  MUR_log_dif_pred  KSH_log_dif_pred  \
# Date
# 2022-03-13          0.000000          0.000000          0.000000
# 2022-03-20          0.000000          0.000000          0.000000
# 2022-03-27         -0.007237         -0.001663          0.001798
# 2022-04-03         -0.022585         -0.001076          0.003351
# 2022-04-10         -0.017404          0.001141          0.007414
#
#             NRA_log_dif_pred  MZM_log_dif_pred  BPU_log_dif_pred
# Date
# 2022-03-13          0.000000          0.000000          0.000000
# 2022-03-20          0.000000          0.000000          0.000000
# 2022-03-27         -0.000314         -0.000755          0.004197
# 2022-04-03          0.000469          0.000839         -0.006793
# 2022-04-10          0.000858         -0.000369         -0.007340
#
# [5 rows x 24 columns]

# %%
zar_arima_diff = pd.Series(week_exchange_df['ZAR_log_dif_pred'], copy=True)
zar_log = week_exchange_df['ZAR_log']

# %%
zar_pred_arima = rescale(zar_arima_diff, week_exchange_df['ZAR_log'] )

# %%
plt.plot(week_exchange_df.index, week_exchange_df['ZAR'])
plt.plot(week_exchange_df.index, zar_pred_arima)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing as ESfrom statsmodels.tsa.holtwinters import ExponentialSmoothing as ES

# %%
week_exchange_df.shape
# Out:
# (54, 24)

# %%
# train and test split
dataset_length = week_exchange_df.shape[0]
train_split = int(0.8*dataset_length)
train_set, test_set = week_exchange_df['ZAR'][0:train_split], week_exchange_df['ZAR'][train_split-3:]
plt.plot(train_set,color="green")
plt.plot(test_set)

# %%
test_set
# Out:
# Date
# 2022-12-18    17.270291
# 2022-12-25    17.230163
# 2023-01-01    17.071479
# 2023-01-08    17.028235
# 2023-01-15    16.899598
# 2023-01-22    17.078491
# 2023-01-29    17.157847
# 2023-02-05    17.289661
# 2023-02-12    17.717551
# 2023-02-19    17.990637
# 2023-02-26    18.245043
# 2023-03-05    18.239384
# 2023-03-12    18.387088
# 2023-03-19    18.225102
# Name: ZAR, dtype: float64

# %%
model = ARIMA(train_set, order=(2,2,1))
result = model.fit()
forecast = result.forecast(4)

# %%
forecast
# Out:
# 2023-01-08    17.001578
# 2023-01-15    16.876035
# 2023-01-22    16.779267
# 2023-01-29    16.671714
# Freq: W-SUN, Name: predicted_mean, dtype: float64
